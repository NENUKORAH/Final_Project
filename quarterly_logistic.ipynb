# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
tsla_df = pd.read_csv('Resources/quarterly.txt')
tsla_df.head()
# Out:
#   Ticker        Date  Revenue   EPS  NetIncome  GrossProfit  OperatingIncome  \
# 0   TSLA  2021-06-30    11958  1.02       1142         2884             1312
# 1   TSLA  2021-03-31    10389  0.39        438         2215              594
# 2   TSLA  2020-12-31    10744  0.25        270         2066              575
# 3   TSLA  2020-09-30     8771  0.27        300         2063              809
# 4   TSLA  2020-06-30     6036  0.10        104         1267              327
#
#    EBITDA  Shares Quarter  Year   Qlabel
# 0    1993    1119      Q2  2021  Q2-2021
# 1    1215    1133      Q1  2021  Q1-2021
# 2    1229    1083      Q4  2020  Q4-2020
# 3    1537    1105      Q3  2020  Q3-2020
# 4     894    1036      Q2  2020  Q2-2020

# %%
y = tsla_df
X = tsla_df

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-5e1d3d40d8ce> in <module>
#       4
#       5 # Split training/test datasets
# ----> 6 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2195                      random_state=random_state)
#    2196
# -> 2197         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2198
#    2199     return list(chain.from_iterable((_safe_indexing(a, train),
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    1385         """
#    1386         X, y, groups = indexable(X, y, groups)
# -> 1387         for train, test in self._iter_indices(X, y, groups):
#    1388             yield train, test
#    1389
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\model_selection\_split.py in _iter_indices(self, X, y, groups)
#    1713         class_counts = np.bincount(y_indices)
#    1714         if np.min(class_counts) < 2:
# -> 1715             raise ValueError("The least populated class in y has only 1"
#    1716                              " member, which is too few. The minimum"
#    1717                              " number of groups for any class cannot"
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 764us/step - loss: 0.7048 - accuracy: 0.5990
# Epoch 2/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.6663 - accuracy: 0.6198
# Epoch 3/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.6347 - accuracy: 0.6510
# Epoch 4/50
# 18/18 [==============================] - 0s 765us/step - loss: 0.6089 - accuracy: 0.6858
# Epoch 5/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.5868 - accuracy: 0.7014
# Epoch 6/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.5697 - accuracy: 0.7135
# Epoch 7/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.5540 - accuracy: 0.7135
# Epoch 8/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.5408 - accuracy: 0.7153
# Epoch 9/50
# 18/18 [==============================] - 0s 941us/step - loss: 0.5301 - accuracy: 0.7222
# Epoch 10/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.5203 - accuracy: 0.7378
# Epoch 11/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.5111 - accuracy: 0.7413
# Epoch 12/50
# 18/18 [==============================] - 0s 824us/step - loss: 0.5040 - accuracy: 0.7465
# Epoch 13/50
# 18/18 [==============================] - 0s 883us/step - loss: 0.4972 - accuracy: 0.7535
# Epoch 14/50
# 18/18 [==============================] - 0s 765us/step - loss: 0.4914 - accuracy: 0.7569
# Epoch 15/50
# 18/18 [==============================] - 0s 883us/step - loss: 0.4864 - accuracy: 0.7587
# Epoch 16/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4819 - accuracy: 0.7639
# Epoch 17/50
# 18/18 [==============================] - 0s 999us/step - loss: 0.4781 - accuracy: 0.7656
# Epoch 18/50
# 18/18 [==============================] - 0s 824us/step - loss: 0.4742 - accuracy: 0.7708
# Epoch 19/50
# 18/18 [==============================] - 0s 882us/step - loss: 0.4711 - accuracy: 0.7708
# Epoch 20/50
# 18/18 [==============================] - 0s 883us/step - loss: 0.4682 - accuracy: 0.7726
# Epoch 21/50
# 18/18 [==============================] - 0s 823us/step - loss: 0.4654 - accuracy: 0.7778
# Epoch 22/50
# 18/18 [==============================] - 0s 883us/step - loss: 0.4633 - accuracy: 0.7830
# Epoch 23/50
# 18/18 [==============================] - 0s 824us/step - loss: 0.4609 - accuracy: 0.7865
# Epoch 24/50
# 18/18 [==============================] - 0s 824us/step - loss: 0.4591 - accuracy: 0.7847
# Epoch 25/50
# 18/18 [==============================] - 0s 765us/step - loss: 0.4574 - accuracy: 0.7830
# Epoch 26/50
# 18/18 [==============================] - 0s 765us/step - loss: 0.4559 - accuracy: 0.7847
# Epoch 27/50
# 18/18 [==============================] - 0s 765us/step - loss: 0.4546 - accuracy: 0.7865
# Epoch 28/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4534 - accuracy: 0.7865
# Epoch 29/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4519 - accuracy: 0.7882
# Epoch 30/50
# 18/18 [==============================] - 0s 765us/step - loss: 0.4507 - accuracy: 0.7899
# Epoch 31/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4501 - accuracy: 0.7917
# Epoch 32/50
# 18/18 [==============================] - 0s 765us/step - loss: 0.4484 - accuracy: 0.7934
# Epoch 33/50
# 18/18 [==============================] - 0s 764us/step - loss: 0.4478 - accuracy: 0.7934
# Epoch 34/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4468 - accuracy: 0.7951
# Epoch 35/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.4458 - accuracy: 0.7969
# Epoch 36/50
# 18/18 [==============================] - 0s 765us/step - loss: 0.4451 - accuracy: 0.7951
# Epoch 37/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4441 - accuracy: 0.7969
# Epoch 38/50
# 18/18 [==============================] - 0s 765us/step - loss: 0.4439 - accuracy: 0.7969
# Epoch 39/50
# 18/18 [==============================] - 0s 811us/step - loss: 0.4427 - accuracy: 0.7969
# Epoch 40/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.4420 - accuracy: 0.7986
# Epoch 41/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.4414 - accuracy: 0.7986
# Epoch 42/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.4411 - accuracy: 0.7986
# Epoch 43/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4404 - accuracy: 0.7986
# Epoch 44/50
# 18/18 [==============================] - 0s 648us/step - loss: 0.4395 - accuracy: 0.8021
# Epoch 45/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4388 - accuracy: 0.8003
# Epoch 46/50
# 18/18 [==============================] - 0s 706us/step - loss: 0.4383 - accuracy: 0.8003
# Epoch 47/50
# 18/18 [==============================] - 0s 765us/step - loss: 0.4376 - accuracy: 0.8003
# Epoch 48/50
# 18/18 [==============================] - 0s 764us/step - loss: 0.4375 - accuracy: 0.7986
# Epoch 49/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4366 - accuracy: 0.7969
# Epoch 50/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4362 - accuracy: 0.7986
# 6/6 - 0s - loss: 0.4898 - accuracy: 0.7240
# Loss: 0.489778608083725, Accuracy: 0.7239583134651184
